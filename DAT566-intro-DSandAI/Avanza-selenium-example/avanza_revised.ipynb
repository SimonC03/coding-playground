# %% [markdown]
# IDSAI_2024_lecture3_DEMO1 -------------------------------- 01000110.01001010 ---- revised: Aug2024_F.Jalalypour

# %% [markdown]
# Here, we will start scraping the Avanza webpage by reading the content of the file and then parsing it with Beuatiful Soup.

# %%
# Importing BeautifulSoup
from bs4 import BeautifulSoup                  #This line imports the BeautifulSoup class from the bs4 module.  

# Reading the HTML File
with open('avanza.html','r') as f:             #This lines open the file named avanza.html in read mode ('r'). 
    html = f.read()
    
# Parsing the HTML    
soup = BeautifulSoup(html, 'html.parser')      #This line creates a BeautifulSoup object named soup by parsing the HTML content stored in the html variable

# %% [markdown]
# soup

# %% [markdown]
# Let’s break down the process of extracting and processing data from an HTML webpage, using the provided example of extracting stock names and numerical data. Comparing the visible content of the Avanza webpage, let us search for, for example, AstraZeneca, in the source. We will find that the names are contained in HTML content with elements that looks like this:
#
# ```
#     <td class="orderbookName">
#         <a class="ellipsis" href="/aktier/om-aktien.html/5431/astrazeneca">
#             <span class="flag small SE"></span>AstraZeneca
#         </a>
#     </td>
#
# ```
# **Unfortunately, stock names and numerical data are in separate tables, so we need to handle them separately; first collecting the names and then the numerical data.**
#
# We will collect all `td` (table cells) elements that have the class `orderbookName`. The name of the stock is as a textual content of the element. In this case, we can access it simply by the `.text` member. In a more complicated case, we might have to issue, e.g., `cell.find_all(text=True)`.
#
# The text contains a lot of whitespace around it, so it makes sense to `strip` that whitespace away.

# %%
# Initialize an Empty List
names = list()                                           #This line creates an empty list named "names"

#Find All Matching Elements                              #find_all method returns a list of all matching elements

for cell in soup.find_all('td',class_='orderbookName'):  #This line searches through the soup for all <td> elements (table cells) that have the class orderbookName.
    names.append(cell.text.strip())                      #Extract and Clean Text #text: textual content; strip: whitespace away
names
# Out:
# ['AAK',
#  'ABB Ltd',
#  'AddLife B',
#  'Addnode Group B',
#  'Addtech B',
#  'AFRY',
#  'Alfa Laval',
#  'Alleima',
#  'Arion Banki SDB',
#  'Arjo B',
#  'ASSA ABLOY B',
#  'AstraZeneca',
#  'Atlas Copco A',
#  'Atlas Copco B',
#  'Atrium Ljungberg B',
#  'Autoliv SDB',
#  'Avanza Bank Holding',
#  'Axfood',
#  'Beijer Ref B',
#  'Betsson B',
#  'Better Collective',
#  'Bilia A',
#  'Billerud',
#  'BioArctic B',
#  'Biotage',
#  'Boliden',
#  'Bravida Holding',
#  'Bure Equity',
#  'Camurus',
#  'Castellum',
#  'Catena',
#  'Corem Property Group A',
#  'Corem Property Group B',
#  'Corem Property Group D',
#  'Corem Property Group Pref',
#  'Creades A',
#  'Diös Fastigheter',
#  'Dometic Group',
#  'Electrolux A',
#  'Electrolux B',
#  'Electrolux Professional B',
#  'Elekta B',
#  'Embracer Group B',
#  'Epiroc A',
#  'Epiroc B',
#  'EQT',
#  'Ericsson A',
#  'Ericsson B',
#  'Essity A',
#  'Essity B',
#  'Evolution',
#  'Fabege',
#  'Fast. Balder B',
#  'Fastpartner A',
#  'Fastpartner D',
#  'Fenix Outdoor International B',
#  'Fortnox',
#  'Getinge B',
#  'Handelsbanken A',
#  'Handelsbanken B',
#  'Hemnet Group',
#  'Hennes & Mauritz B',
#  'Hexagon B',
#  'HEXPOL B',
#  'HMS Networks',
#  'Holmen A',
#  'Holmen B',
#  'Hufvudstaden A',
#  'Husqvarna A',
#  'Husqvarna B',
#  'Industrivärden A',
#  'Industrivärden C',
#  'Indutrade',
#  'Instalco',
#  'International Petroleum Corp.',
#  'Intrum',
#  'Investor A',
#  'Investor B',
#  'JM',
#  'Kindred Group',
#  'Kinnevik A',
#  'Kinnevik B',
#  'Lagercrantz Group B',
#  'Latour B',
#  'Lifco B',
#  'Lindab International',
#  'Loomis',
#  'Lundbergföretagen B',
#  'Lundin Gold',
#  'Lundin Mining Corporation',
#  'Medicover B',
#  'Millicom Int. Cellular SDB',
#  'Mips',
#  'Modern Times Group A',
#  'Modern Times Group B',
#  'Munters Group',
#  'Mycronic',
#  'NCAB Group',
#  'NCC A',
#  'NCC B',
#  'New Wave B',
#  'NIBE Industrier B',
#  'Nolato B',
#  'Nordea Bank Abp',
#  'Nordnet',
#  'NP3 Fastigheter',
#  'NP3 Fastigheter Pref',
#  'Nyfosa',
#  'OX2',
#  'Pandox B',
#  'Peab B',
#  'Ratos A',
#  'Ratos B',
#  'SAAB B',
#  'Sagax A',
#  'Sagax B',
#  'Sagax D',
#  'Samhällsbyggnadsbo. i Norden B',
#  'Samhällsbyggnadsbo. i Norden D',
#  'Sampo Oyj SDB',
#  'Sandvik',
#  'SCA A',
#  'SCA B',
#  'SEB A',
#  'SEB C',
#  'SECTRA B',
#  'Securitas B',
#  'Sinch',
#  'Skanska B',
#  'SKF A',
#  'SKF B',
#  'SSAB A',
#  'SSAB B',
#  'Stora Enso A',
#  'Stora Enso R',
#  'Storskogen Group B',
#  'SWECO A',
#  'SWECO B',
#  'Swedbank A',
#  'Swedish Orphan Biovitrum',
#  'Systemair',
#  'Tele2 A',
#  'Tele2 B',
#  'Telia Company',
#  'Thule Group',
#  'TietoEVRY Oyj',
#  'TRATON',
#  'Trelleborg B',
#  'Troax Group',
#  'Truecaller B',
#  'Vitec Software Group B',
#  'Vitrolife',
#  'Volvo A',
#  'Volvo B',
#  'Volvo Car B',
#  'Wallenstam B',
#  'Wihlborgs Fastigheter']

# %%
len(names) #Length of names
# Out:
# 157

# %% [markdown]
# In a snapshot, AstraZeneca would have the following numbers:
#
# |Senast |+/-%|1 år %|Börsvärde MSEK|P/E-tal|Direktavk. %|Ägare |Lista
# |-------|----|------|--------------|-------|------------|------|-----
# |1423,00|0   |-3,98 |2 202 059     |34,05  |2,13        |62 653|Large Cap Stockholm
#
# Here *Senast* is the latest quote of the share value, +/-% daily change in value, *1 år %* percentual change over the year, *Börsvärde MSEK* market value of the company in millions of kronor, *P/E-tal* the P/E value of the company, *Direktavkastning* is the dividend yield, *Ägare* the numer of owners, and *List* which list the stock is listed under in Stockholm stock exchange.
#
# We can find these in the following element (A substantial amount of whitespace has been removed):
#
# ```
# <tr class="row rowId11" id="11">
#     <td class="">
#         <span class="pushBox" data-aza-push="vm.pushData.latest['5431'].lastPrice" data-aza-push-fractions="2">1423,00</span>
#     </td>
#     <td class="neutral">
#         <span data-ng-class="{'neutral': vm.commonService.isNeutral(vm.pushData.latest['5431'].changePercent), 'negative': vm.commonService.isNegative(vm.pushData.latest['5431'].changePercent), 'positive': vm.commonService.isPositive(vm.pushData.latest['5431'].changePercent)}" data-aza-push="vm.pushData.latest['5431'].changePercent" data-aza-push-fractions="2" class="neutral" style="">0</span>
#     </td>
#     <td class="negative">
#         <span>-3,98</span>
#     </td>
#     <td class="">
#         <span>2&nbsp;202&nbsp;059</span>
#     </td>
#     <td class="">
#         <span>34,05</span>
#     </td>
#     <td class="">
#         <span>2,13</span>
#     </td>
#     <td class="">
#         <span>62&nbsp;653</span>
#     </td>
#     <td class="">
#         <span>Large Cap Stockholm</span>
#     </td>
# </tr>
#
# ```

# %% [markdown]
# **Side Note:**
#
# `<tr>` (Table Row) : This tag represents a `single row` in a table.
#
# `<td>` (Table Data): This tag represents a `single cell (or column)` in a row.
#
# ```
# <tr class="row">
#   <td>Row 1 Column 1</td>
#   <td>Row 1 Column 2</td>
# </tr>
# ```

# %% [markdown]
# So we will need to find `tr` elements that have class `row`.

# %%
soup.find('tr',class_='row')
# Out:
# <tr class="row rowId0" id="0">
# <td class="buySellButtons">
# <ul class="u-cleanList u-floatList buySellButtons">
# <li>
# <a class="button buyBtn smallBtn" href="/handla/order.html/kop/26268" title="Köp">Köp</a>
# </li>
# </ul>
# </td>
# <td class="orderbookName">
# <a class="ellipsis" href="/aktier/om-aktien.html/26268/aak">
# <span class="flag small SE"></span>AAK
# 							</a>
# </td>
# </tr>

# %% [markdown]
# As you see, it shows us unnecessary characters such as the name of a stock and a link to more details about the stock as well as list of buttons for buying or selling with a link to place an order.
#
# `A generic search approach might end up finding more elements than desired` when other elements might have similar structures. To accurately find a specific piece of information in an HTML document, we may locate a particular element that contains a known value. For instance, a row that contains the name "AstraZeneca" or its share value.
#
# Once you have identified the specific element containing the value, you can then locate its `parent table` (all `tr` elements belong to a `table`), and with the entire table structure more accurately.
#
# we can match it with `Regular Expressions`. This involves finding specific elements within a webpage's HTML structure, and sometimes dealing with complex or inconsistent formatting. Use `regex` to clean up or match the text content accurately and filter out unwanted characters and focus on the actual data you need.

# %% [markdown]
# ## Part 2: Regular Expressions

# %%
#find a specific string within an HTML document 
import re    #Imports the re module, Python's library for working with regular expressions.

# Define the pattern to find a specific string
pattern = r'.*1423,00.*' #matches any string containing 1423,00 with any characters before or after it.
element = soup.find(string=re.compile(pattern)) #Searches for text(string) in the HTML that matches the regular expression pattern provided

# %% [markdown]
# Now we can navigate up the HTML tree from a specific element and retrieve its parent elements:

# %%
element
# Out:
# '\n                                                    \n\n\n\n\n\n\n\n\n\n\n\n\t\n\n\n\t\n\n1423,00 \n                                                '

# %%
table = element.parent.parent
table.name
# Out:
# 'td'

# %%
table = element.parent.parent.parent.parent.parent  #to navigate up five levels from the element 
table.name                                          # and then check the name of the tag at that level.
# Out:
# 'table'

# %% [markdown]
# Yay, so this is the table that we are looking for. So now let's look for the children underneath :)

# %% [markdown]
# table.find('tr',class_='row')

# %% [markdown]
# This is the data we want. So let's start extracting `td` element by element.

# %%
for cell in table.find('tr',class_='row').select('td'):
    print(cell.text.strip())
# Out:
# 229,60
# 1,32
# 24,04
# 58 817
# 22,61
# 1,21
# 9 526
# Large Cap Stockholm

# %% [markdown]
# We will need to do this for all such rows, so we will use `find_all` and then construct the values.

# %%
values = list()
for row in table.find_all('tr',class_='row'):
    values.append([cell.text.strip() for cell in row.select('td')])
values
# Out:
# [['229,60',
#   '1,32',
#   '24,04',
#   '58\xa0817',
#   '22,61',
#   '1,21',
#   '9\xa0526',
#   'Large Cap Stockholm'],
#  ['441,30',
#   '1,12',
#   '26,81',
#   '803\xa0634',
#   '18,74',
#   '2,19',
#   '49\xa0168',
#   'Large Cap Stockholm'],
#  ['112,90',
#   '4,25',
#   '2,92',
#   '13\xa0776',
#   '44,74',
#   '1,11',
#   '7\xa0048',
#   'Large Cap Stockholm'],
#  ['84,75',
#   '3,8',
#   '-18,59',
#   '11\xa0368',
#   '39,44',
#   '1,22',
#   '3\xa0846',
#   'Large Cap Stockholm'],
#  ['216,40',
#   '2,27',
#   '32,44',
#   '57\xa0724',
#   '33,81',
#   '1,18',
#   '7\xa0876',
#   'Large Cap Stockholm'],
#  ['139,90',
#   '3,25',
#   '-25,47',
#   '15\xa0810',
#   '12,95',
#   '4,06',
#   '10\xa0675',
#   'Large Cap Stockholm'],
#  ['379,20',
#   '-0,86',
#   '15,4',
#   '158\xa0996',
#   '26,04',
#   '1,57',
#   '23\xa0443',
#   'Large Cap Stockholm'],
#  ['76,26',
#   '2,03',
#   '84,25',
#   '19\xa0117',
#   '11,83',
#   '1,87',
#   '37\xa0970',
#   'Large Cap Stockholm'],
#  ['11,80',
#   '0,85',
#   '5,55',
#   '17\xa0085',
#   '8,78',
#   '5,4',
#   '4\xa0430',
#   'Large Cap Stockholm'],
#  ['43,12',
#   '1,36',
#   '6,21',
#   '11\xa0631',
#   '29,86',
#   '2',
#   '12\xa0408',
#   'Large Cap Stockholm'],
#  ['285,60',
#   '1,28',
#   '18,8',
#   '318\xa0086',
#   '23,39',
#   '1,7',
#   '27\xa0552',
#   'Large Cap Stockholm'],
#  ['1423,00',
#   '0',
#   '-3,98',
#   '2\xa0202\xa0059',
#   '34,05',
#   '2,13',
#   '62\xa0653',
#   'Large Cap Stockholm'],
#  ['166,25',
#   '1,46',
#   '24,29',
#   '769\xa0521',
#   '29,22',
#   '1,4',
#   '15\xa0412',
#   'Large Cap Stockholm'],
#  ['142,40',
#   '1,32',
#   '21,71',
#   '769\xa0521',
#   '25,06',
#   '1,64',
#   '45\xa0376',
#   'Large Cap Stockholm'],
#  ['222,20',
#   '1,09',
#   '16,21',
#   '29\xa0282',
#   '-19,51',
#   '2,41',
#   '4\xa0677',
#   'Large Cap Stockholm'],
#  ['1089,00',
#   '1,49',
#   '32',
#   '93\xa0022',
#   '20,17',
#   '2,66',
#   '7\xa0304',
#   'Large Cap Stockholm'],
#  ['223,40',
#   '-1,15',
#   '2,95',
#   '35\xa0536',
#   '17,94',
#   '3,32',
#   '64\xa0688',
#   'Large Cap Stockholm'],
#  ['266,30',
#   '-2,95',
#   '-6,56',
#   '57\xa0681',
#   '26,99',
#   '2,97',
#   '85\xa0595',
#   'Large Cap Stockholm'],
#  ['128,90',
#   '1,82',
#   '-21,69',
#   '65\xa0418',
#   '35,99',
#   '0,74',
#   '10\xa0052',
#   'Large Cap Stockholm'],
#  ['111,40',
#   '-0,18',
#   '23,78',
#   '15\xa0929',
#   '8,41',
#   '0',
#   '18\xa0391',
#   'Large Cap Stockholm'],
#  ['249,50',
#   '2,04',
#   '80,8',
#   '13\xa0832',
#   '22,00',
#   '0',
#   '1\xa0911',
#   'Large Cap Stockholm'],
#  ['127,70',
#   '2,08',
#   '8,13',
#   '12\xa0279',
#   '11,06',
#   '7,03',
#   '13\xa0066',
#   'Large Cap Stockholm'],
#  ['97,18',
#   '1,59',
#   '-26,24',
#   '24\xa0378',
#   '13,56',
#   '5,75',
#   '22\xa0250',
#   'Large Cap Stockholm'],
#  ['254,20',
#   '3,25',
#   '-17,36',
#   '22\xa0397',
#   '84,06',
#   '0',
#   '13\xa0781',
#   'Large Cap Stockholm'],
#  ['139,70',
#   '5,67',
#   '-20,13',
#   '11\xa0199',
#   '55,67',
#   '1,21',
#   '3\xa0285',
#   'Large Cap Stockholm'],
#  ['288,05',
#   '-0,12',
#   '-34,25',
#   '78\xa0771',
#   '11,28',
#   '5,2',
#   '52\xa0692',
#   'Large Cap Stockholm'],
#  ['80,65',
#   '3,07',
#   '-25,53',
#   '16\xa0577',
#   '12,02',
#   '4,15',
#   '7\xa0784',
#   'Large Cap Stockholm'],
#  ['288,60',
#   '3,29',
#   '21,06',
#   '21\xa0401',
#   '4,95',
#   '0,81',
#   '37\xa0199',
#   'Large Cap Stockholm'],
#  ['587,00',
#   '2,98',
#   '143,16',
#   '32\xa0652',
#   '68,86',
#   '0',
#   '7\xa0923',
#   'Large Cap Stockholm'],
#  ['137,75',
#   '1,89',
#   '-0,25',
#   '67\xa0761',
#   '-6,54',
#   '0',
#   '79\xa0824',
#   'Large Cap Stockholm'],
#  ['443,40',
#   '0,59',
#   '3,84',
#   '22\xa0134',
#   '709,32',
#   '1,87',
#   '3\xa0819',
#   'Large Cap Stockholm'],
#  ['10,30',
#   '0,49',
#   '-10,43',
#   '15\xa0207',
#   '-1,30',
#   '3,9',
#   '2\xa0545',
#   'Large Cap Stockholm'],
#  ['10,03',
#   '0,8',
#   '-3,93',
#   '15\xa0207',
#   '-1,27',
#   '4,02',
#   '13\xa0532',
#   'Large Cap Stockholm'],
#  ['187,00',
#   '0,75',
#   '-6,73',
#   '15\xa0207',
#   '-23,62',
#   '10,78',
#   '4\xa0575',
#   'Large Cap Stockholm'],
#  ['206,00',
#   '0,73',
#   '-11,21',
#   '15\xa0207',
#   '-24,70',
#   '9,78',
#   '7\xa0010',
#   'Large Cap Stockholm'],
#  ['68,95',
#   '1,77',
#   '-16,53',
#   '9\xa0321',
#   '44,65',
#   '2,07',
#   '34\xa0629',
#   'Large Cap Stockholm'],
#  ['82,30',
#   '1,23',
#   '4,24',
#   '11\xa0669',
#   '-41,66',
#   '2,46',
#   '10\xa0080',
#   'Large Cap Stockholm'],
#  ['88,00',
#   '1,31',
#   '19,99',
#   '28\xa0110',
#   '21,23',
#   '1,5',
#   '11\xa0448',
#   'Large Cap Stockholm'],
#  ['118,00',
#   '-0,84',
#   '-37,57',
#   '28\xa0731',
#   '-10,59',
#   '0',
#   '347',
#   'Large Cap Stockholm'],
#  ['101,25',
#   '-1,56',
#   '-36,32',
#   '28\xa0731',
#   '-9,15',
#   '0',
#   '26\xa0883',
#   'Large Cap Stockholm'],
#  ['57,50',
#   '3,14',
#   '17,64',
#   '16\xa0497',
#   '19,78',
#   '1,26',
#   '9\xa0170',
#   'Large Cap Stockholm'],
#  ['80,66',
#   '0,05',
#   '18,44',
#   '31\xa0042',
#   '23,01',
#   '2,98',
#   '10\xa0198',
#   'Large Cap Stockholm'],
#  ['24,920',
#   '1,86',
#   '-46,81',
#   '33\xa0460',
#   '8,29',
#   '0',
#   '98\xa0933',
#   'Large Cap Stockholm'],
#  ['191,85',
#   '1,48',
#   '-7,32',
#   '220\xa0322',
#   '23,80',
#   '1,8',
#   '5\xa0636',
#   'Large Cap Stockholm'],
#  ['168,60',
#   '1,38',
#   '-4,8',
#   '220\xa0322',
#   '20,94',
#   '2,04',
#   '17\xa0912',
#   'Large Cap Stockholm'],
#  ['264,00',
#   '2,68',
#   '4,39',
#   '321\xa0558',
#   '-800,32',
#   '1,17',
#   '43\xa0218',
#   'Large Cap Stockholm'],
#  ['66,00',
#   '0,3',
#   '-3,65',
#   '214\xa0241',
#   '-9,39',
#   '4,1',
#   '6\xa0080',
#   'Large Cap Stockholm'],
#  ['64,04',
#   '1,49',
#   '1,09',
#   '214\xa0241',
#   '-9,01',
#   '4,28',
#   '75\xa0045',
#   'Large Cap Stockholm'],
#  ['264,00',
#   '1,93',
#   '-8,97',
#   '182\xa0356',
#   '19,88',
#   '2,8',
#   '5\xa0066',
#   'Large Cap Stockholm'],
#  ['264,10',
#   '1,69',
#   '-8,39',
#   '182\xa0356',
#   '19,93',
#   '2,79',
#   '31\xa0685',
#   'Large Cap Stockholm'],
#  ['1147,00',
#   '-1,31',
#   '2,28',
#   '248\xa0808',
#   '20,73',
#   '1,95',
#   '78\xa0183',
#   'Large Cap Stockholm'],
#  ['102,40',
#   '1,89',
#   '4,17',
#   '33\xa0773',
#   '-5,05',
#   '2,39',
#   '10\xa0969',
#   'Large Cap Stockholm'],
#  ['68,62',
#   '2,39',
#   '20,47',
#   '78\xa0980',
#   '-43,57',
#   '0',
#   '19\xa0748',
#   'Large Cap Stockholm'],
#  ['63,10',
#   '1,12',
#   '-25,24',
#   '12\xa0306',
#   '-5,86',
#   '1,6',
#   '2\xa0284',
#   'Large Cap Stockholm'],
#  ['59,70',
#   '0,34',
#   '-19,87',
#   '12\xa0306',
#   '-5,58',
#   '8,4',
#   '3\xa0436',
#   'Large Cap Stockholm'],
#  ['750,00',
#   '0',
#   '-19,09',
#   '10\xa0095',
#   '19,40',
#   '2',
#   '5\xa0147',
#   'Large Cap Stockholm'],
#  ['53,88',
#   '2,01',
#   '7,25',
#   '32\xa0207',
#   '67,65',
#   '0,23',
#   '41\xa0559',
#   'Large Cap Stockholm'],
#  ['229,10',
#   '1,37',
#   '3,29',
#   '61\xa0791',
#   '27,09',
#   '1,88',
#   '26\xa0585',
#   'Large Cap Stockholm'],
#  ['111,00',
#   '1,32',
#   '-0,49',
#   '219\xa0984',
#   '7,81',
#   '5,02',
#   '65\xa0540',
#   'Large Cap Stockholm'],
#  ['136,40',
#   '1,34',
#   '3,33',
#   '219\xa0984',
#   '9,59',
#   '4,09',
#   '25\xa0098',
#   'Large Cap Stockholm'],
#  ['247,60',
#   '-1,82',
#   '68,44',
#   '24\xa0805',
#   '81,61',
#   '0,4',
#   '6\xa0655',
#   'Large Cap Stockholm'],
#  ['169,54',
#   '1,07',
#   '30,18',
#   '273\xa0364',
#   '43,51',
#   '3,88',
#   '92\xa0218',
#   'Large Cap Stockholm'],
#  ['115,75',
#   '0,7',
#   '-2,61',
#   '317\xa0402',
#   '29,29',
#   '1,18',
#   '34\xa0950',
#   'Large Cap Stockholm'],
#  ['117,90',
#   '1,64',
#   '0,08',
#   '40\xa0765',
#   '15,13',
#   '3,1',
#   '5\xa0039',
#   'Large Cap Stockholm'],
#  ['511,00',
#   '3,9',
#   '44,19',
#   '23\xa0784',
#   '37,62',
#   '0,81',
#   '5\xa0051',
#   'Large Cap Stockholm'],
#  ['411,00',
#   '0,74',
#   '-6,16',
#   '67\xa0192',
#   '14,68',
#   '1,96',
#   '3\xa0076',
#   'Large Cap Stockholm'],
#  ['414,90',
#   '1,02',
#   '-2,77',
#   '67\xa0192',
#   '14,77',
#   '1,95',
#   '20\xa0024',
#   'Large Cap Stockholm'],
#  ['136,30',
#   '2,33',
#   '-13,52',
#   '28\xa0776',
#   '-14,07',
#   '2,03',
#   '14\xa0932',
#   'Large Cap Stockholm'],
#  ['79,90',
#   '0,76',
#   '-1,11',
#   '46\xa0320',
#   '25,22',
#   '3,78',
#   '7\xa0067',
#   'Large Cap Stockholm'],
#  ['80,34',
#   '0,75',
#   '-0,54',
#   '46\xa0320',
#   '25,36',
#   '3,76',
#   '24\xa0894',
#   'Large Cap Stockholm'],
#  ['324,70',
#   '0,53',
#   '20,13',
#   '140\xa0160',
#   '4,62',
#   '2,24',
#   '24\xa0840',
#   'Large Cap Stockholm'],
#  ['324,70',
#   '0,56',
#   '20,48',
#   '140\xa0160',
#   '4,62',
#   '2,25',
#   '71\xa0460',
#   'Large Cap Stockholm'],
#  ['259,70',
#   '1,8',
#   '11,84',
#   '93\xa0295',
#   '32,81',
#   '1,02',
#   '12\xa0585',
#   'Large Cap Stockholm'],
#  ['43,44',
#   '4,07',
#   '3,13',
#   '11\xa0066',
#   '17,75',
#   '1,58',
#   '11\xa0004',
#   'Large Cap Stockholm'],
#  ['118,50',
#   '3,54',
#   '15,05',
#   '14\xa0535',
#   '6,79',
#   '0',
#   '8\xa0194',
#   'Large Cap Stockholm'],
#  ['74,02',
#   '5,71',
#   '-45,55',
#   '8\xa0523',
#   '-2,22',
#   '19,28',
#   '43\xa0247',
#   'Large Cap Stockholm'],
#  ['229,60',
#   '1,37',
#   '10,7',
#   '706\xa0899',
#   '5,85',
#   '1,94',
#   '78\xa0460',
#   'Large Cap Stockholm'],
#  ['231,60',
#   '1,31',
#   '13,33',
#   '706\xa0899',
#   '5,91',
#   '1,92',
#   '362\xa0951',
#   'Large Cap Stockholm'],
#  ['178,60',
#   '3,9',
#   '-10,48',
#   '11\xa0566',
#   '9,22',
#   '8,14',
#   '18\xa0675',
#   'Large Cap Stockholm'],
#  ['93,74',
#   '-0,13',
#   '-20,12',
#   '21\xa0600',
#   '13,10',
#   '4,81',
#   '26\xa0981',
#   'Large Cap Stockholm'],
#  ['103,40',
#   '0,39',
#   '-37,03',
#   '29\xa0185',
#   '-4,01',
#   '0',
#   '12\xa0968',
#   'Large Cap Stockholm'],
#  ['103,15',
#   '1,43',
#   '-36,91',
#   '29\xa0185',
#   '-3,96',
#   '0',
#   '116\xa0699',
#   'Large Cap Stockholm'],
#  ['133,40',
#   '0,91',
#   '23,63',
#   '27\xa0952',
#   '33,04',
#   '1,21',
#   '7\xa0152',
#   'Large Cap Stockholm'],
#  ['257,20',
#   '1,82',
#   '19,02',
#   '164\xa0941',
#   '27,34',
#   '1,46',
#   '101\xa0387',
#   'Large Cap Stockholm'],
#  ['255,00',
#   '2,33',
#   '35,75',
#   '113\xa0191',
#   '35,65',
#   '0,72',
#   '16\xa0307',
#   'Large Cap Stockholm'],
#  ['187,20',
#   '0,54',
#   '27,09',
#   '14\xa0681',
#   '17,24',
#   '2,79',
#   '8\xa0490',
#   'Large Cap Stockholm'],
#  ['269,20',
#   '0,6',
#   '-7,81',
#   '20\xa0145',
#   '11,26',
#   '4,48',
#   '6\xa0749',
#   'Large Cap Stockholm'],
#  ['540,20',
#   '1,27',
#   '15,43',
#   '133\xa0772',
#   '13,15',
#   '0,75',
#   '42\xa0199',
#   'Large Cap Stockholm'],
#  ['119,20',
#   '3,47',
#   '4,01',
#   '28\xa0091',
#   '26,23',
#   '3,7',
#   '9\xa0508',
#   'Large Cap Stockholm'],
#  ['82,80',
#   '3,18',
#   '10,16',
#   '62\xa0089',
#   '14,75',
#   '3,55',
#   '16\xa0802',
#   'Large Cap Stockholm'],
#  ['162,90',
#   '4,29',
#   '7,17',
#   '25\xa0045',
#   '158,81',
#   '0,88',
#   '2\xa0825',
#   'Large Cap Stockholm'],
#  ['191,85',
#   '0,5',
#   '32,49',
#   '32\xa0854',
#   '-62,98',
#   '0',
#   '27\xa0464',
#   'Large Cap Stockholm'],
#  ['312,30',
#   '2,06',
#   '-25,55',
#   '8\xa0107',
#   '122,70',
#   '1,8',
#   '16\xa0261',
#   'Large Cap Stockholm'],
#  ['79,00',
#   '-1,25',
#   '-4,82',
#   '10\xa0520',
#   '29,80',
#   '0',
#   '585',
#   'Large Cap Stockholm'],
#  ['80,70',
#   '2,87',
#   '0,01',
#   '10\xa0520',
#   '29,23',
#   '0',
#   '11\xa0186',
#   'Large Cap Stockholm'],
#  ['157,10',
#   '2,81',
#   '51,06',
#   '28\xa0293',
#   '32,20',
#   '0,62',
#   '7\xa0294',
#   'Large Cap Stockholm'],
#  ['280,20',
#   '0,72',
#   '42,89',
#   '27\xa0344',
#   '36,94',
#   '1,26',
#   '7\xa0607',
#   'Large Cap Stockholm'],
#  ['67,90',
#   '2,34',
#   '-3,21',
#   '12\xa0686',
#   '30,41',
#   '1,66',
#   '5\xa0051',
#   'Large Cap Stockholm'],
#  ['127,00',
#   '0,4',
#   '5,83',
#   '12\xa0705',
#   '7,78',
#   '4,74',
#   '2\xa0830',
#   'Large Cap Stockholm'],
#  ['127,30',
#   '0,79',
#   '20,21',
#   '12\xa0705',
#   '7,77',
#   '4,75',
#   '15\xa0534',
#   'Large Cap Stockholm'],
#  ['97,63',
#   '2,19',
#   '-14,66',
#   '12\xa0934',
#   '10,57',
#   '3,4',
#   '24\xa0206',
#   'Large Cap Stockholm'],
#  ['65,02',
#   '-0,88',
#   '-37,96',
#   '132\xa0761',
#   '25,50',
#   '0,99',
#   '115\xa0223',
#   'Large Cap Stockholm'],
#  ['52,60',
#   '2,04',
#   '-11',
#   '14\xa0224',
#   '27,44',
#   '3,69',
#   '6\xa0886',
#   'Large Cap Stockholm'],
#  ['127,28',
#   '0,36',
#   '5,35',
#   '446\xa0150',
#   '7,77',
#   '7,08',
#   '65\xa0919',
#   'Large Cap Stockholm'],
#  ['164,80',
#   '2,42',
#   '7,36',
#   '41\xa0202',
#   '16,60',
#   '2,86',
#   '5\xa0975',
#   'Large Cap Stockholm'],
#  ['216,80',
#   '1,21',
#   '-2,34',
#   '13\xa0339',
#   '94,01',
#   '2,33',
#   '4\xa0668',
#   'Large Cap Stockholm'],
#  ['26,85',
#   '-0,19',
#   '-3,42',
#   '13\xa0339',
#   '35,87',
#   '7,43',
#   '4\xa0897',
#   'Large Cap Stockholm'],
#  ['87,45',
#   '5,11',
#   '-3,58',
#   '16\xa0629',
#   '-19,10',
#   '4,81',
#   '10\xa0578',
#   'Large Cap Stockholm'],
#  ['54,10',
#   '3,84',
#   '-35,56',
#   '14\xa0716',
#   '10,79',
#   '0',
#   '14\xa0392',
#   'Large Cap Stockholm'],
#  ['144,30',
#   '1,33',
#   '9,65',
#   '26\xa0512',
#   '40,53',
#   '1,76',
#   '4\xa0128',
#   'Large Cap Stockholm'],
#  ['54,00',
#   '0,93',
#   '-16,28',
#   '15\xa0839',
#   '6,59',
#   '7,48',
#   '37\xa0169',
#   'Large Cap Stockholm'],
#  ['37,15',
#   '0,68',
#   '-13,5',
#   '11\xa0722',
#   '11,22',
#   '2,28',
#   '3\xa0621',
#   'Large Cap Stockholm'],
#  ['35,52',
#   '2,48',
#   '-11,62',
#   '11\xa0722',
#   '10,54',
#   '2,42',
#   '32\xa0946',
#   'Large Cap Stockholm'],
#  ['675,40',
#   '2,43',
#   '64,45',
#   '89\xa0577',
#   '26,25',
#   '0,8',
#   '61\xa0665',
#   'Large Cap Stockholm'],
#  ['258,00',
#   '1,18',
#   '-5,49',
#   '91\xa0210',
#   '120,64',
#   '1,06',
#   '1\xa0202',
#   'Large Cap Stockholm'],
#  ['258,00',
#   '1,65',
#   '-6,45',
#   '91\xa0210',
#   '120,07',
#   '1,06',
#   '6\xa0533',
#   'Large Cap Stockholm'],
#  ['28,00',
#   '1,27',
#   '-0,53',
#   '91\xa0210',
#   '13,08',
#   '7,23',
#   '10\xa0467',
#   'Large Cap Stockholm'],
#  ['5,022',
#   '3,81',
#   '-75,79',
#   '8\xa0379',
#   '-0,27',
#   '0',
#   '179\xa0285',
#   'Large Cap Stockholm'],
#  ['5,620',
#   '4,93',
#   '-74,08',
#   '8\xa0379',
#   '-0,29',
#   '0',
#   '28\xa0620',
#   'Large Cap Stockholm'],
#  ['436,50',
#   '0,34',
#   '-18,26',
#   '218\xa0784',
#   '14,47',
#   '4,59',
#   '4\xa0162',
#   'Large Cap Stockholm'],
#  ['215,50',
#   '1,84',
#   '5,38',
#   '269\xa0568',
#   '18,32',
#   '2,36',
#   '48\xa0017',
#   'Large Cap Stockholm'],
#  ['145,00',
#   '1,4',
#   '0,83',
#   '101\xa0776',
#   '25,06',
#   '1,75',
#   '6\xa0427',
#   'Large Cap Stockholm'],
#  ['145,00',
#   '1,01',
#   '1,83',
#   '101\xa0776',
#   '25,16',
#   '1,74',
#   '39\xa0242',
#   'Large Cap Stockholm'],
#  ['144,70',
#   '1,72',
#   '12,34',
#   '310\xa0581',
#   '7,98',
#   '4,75',
#   '58\xa0514',
#   'Large Cap Stockholm'],
#  ['146,60',
#   '1,1',
#   '7,48',
#   '310\xa0581',
#   '8,13',
#   '4,66',
#   '12\xa0622',
#   'Large Cap Stockholm'],
#  ['179,64',
#   '1,64',
#   '23,51',
#   '34\xa0768',
#   '78,14',
#   '0',
#   '7\xa0951',
#   'Large Cap Stockholm'],
#  ['99,52',
#   '2,39',
#   '6,42',
#   '57\xa0202',
#   '38,09',
#   '3,55',
#   '30\xa0856',
#   'Large Cap Stockholm'],
#  ['30,935',
#   '1,24',
#   '-36,05',
#   '26\xa0018',
#   '-78,52',
#   '0',
#   '68\xa0056',
#   'Large Cap Stockholm'],
#  ['176,60',
#   '1,49',
#   '-1,78',
#   '73\xa0987',
#   '10,76',
#   '4,31',
#   '45\xa0484',
#   'Large Cap Stockholm'],
#  ['197,80',
#   '1,85',
#   '7,85',
#   '89\xa0922',
#   '12,56',
#   '3,6',
#   '4\xa0165',
#   'Large Cap Stockholm'],
#  ['196,60',
#   '0,95',
#   '8,35',
#   '89\xa0922',
#   '12,60',
#   '3,59',
#   '24\xa0592',
#   'Large Cap Stockholm'],
#  ['76,50',
#   '1,97',
#   '20,74',
#   '78\xa0340',
#   '-4,10',
#   '11,6',
#   '23\xa0268',
#   'Large Cap Stockholm'],
#  ['76,06',
#   '2,04',
#   '24,69',
#   '78\xa0340',
#   '-4,07',
#   '11,67',
#   '106\xa0509',
#   'Large Cap Stockholm'],
#  ['139,20',
#   '1,75',
#   '-15,84',
#   '109\xa0933',
#   '21,07',
#   '4,92',
#   '8\xa0523',
#   'Large Cap Stockholm'],
#  ['139,50',
#   '1,45',
#   '-11,65',
#   '109\xa0933',
#   '21,18',
#   '4,89',
#   '14\xa0121',
#   'Large Cap Stockholm'],
#  ['8,760',
#   '3,42',
#   '4,21',
#   '14\xa0194',
#   '11,63',
#   '0,94',
#   '25\xa0336',
#   'Large Cap Stockholm'],
#  ['128,50',
#   '0,78',
#   '12,72',
#   '46\xa0550',
#   '26,15',
#   '2,12',
#   '1\xa0021',
#   'Large Cap Stockholm'],
#  ['129,30',
#   '2,78',
#   '13,32',
#   '46\xa0550',
#   '25,80',
#   '2,15',
#   '8\xa0895',
#   'Large Cap Stockholm'],
#  ['208,30',
#   '1,12',
#   '8,77',
#   '236\xa0361',
#   '7,10',
#   '4,73',
#   '94\xa0999',
#   'Large Cap Stockholm'],
#  ['290,60',
#   '1,61',
#   '28,3',
#   '101\xa0735',
#   '35,06',
#   '0',
#   '8\xa0496',
#   'Large Cap Stockholm'],
#  ['79,90',
#   '1,78',
#   '3,77',
#   '17\xa0182',
#   '12,79',
#   '1,4',
#   '4\xa0305',
#   'Large Cap Stockholm'],
#  ['90,80',
#   '0,22',
#   '-4,82',
#   '61\xa0254',
#   '15,46',
#   '7,51',
#   '1\xa0022',
#   'Large Cap Stockholm'],
#  ['87,64',
#   '-0,07',
#   '-4,72',
#   '61\xa0254',
#   '14,97',
#   '7,75',
#   '71\xa0773',
#   'Large Cap Stockholm'],
#  ['27,39',
#   '0,33',
#   '-0,22',
#   '107\xa0583',
#   '-7,11',
#   '7,33',
#   '63\xa0222',
#   'Large Cap Stockholm'],
#  ['260,20',
#   '-1,29',
#   '7,08',
#   '28\xa0189',
#   '26,27',
#   '3,49',
#   '17\xa0105',
#   'Large Cap Stockholm'],
#  ['241,60',
#   '1,43',
#   '-22,46',
#   '28\xa0139',
#   '13,01',
#   '7,03',
#   '3\xa0572',
#   'Large Cap Stockholm'],
#  ['244,40',
#   '0,66',
#   '43,51',
#   '122\xa0400',
#   '4,34',
#   '3,35',
#   '9\xa0319',
#   'Large Cap Stockholm'],
#  ['337,10',
#   '3,06',
#   '36,37',
#   '83\xa0452',
#   '7,70',
#   '1,83',
#   '14\xa0672',
#   'Large Cap Stockholm'],
#  ['242,40',
#   '2,02',
#   '23,55',
#   '14\xa0436',
#   '34,87',
#   '1,51',
#   '4\xa0460',
#   'Large Cap Stockholm'],
#  ['31,81',
#   '-0,22',
#   '-20,2',
#   '12\xa0153',
#   '22,46',
#   '0',
#   '11\xa0205',
#   'Large Cap Stockholm'],
#  ['592,50',
#   '3,77',
#   '48,35',
#   '21\xa0515',
#   '65,25',
#   '0,4',
#   '7\xa0604',
#   'Large Cap Stockholm'],
#  ['174,60',
#   '2,11',
#   '-14,83',
#   '23\xa0250',
#   '57,76',
#   '0,5',
#   '10\xa0871',
#   'Large Cap Stockholm'],
#  ['255,60',
#   '1,27',
#   '22,18',
#   '510\xa0042',
#   '11,52',
#   '2,77',
#   '15\xa0231',
#   'Large Cap Stockholm'],
#  ['250,15',
#   '1,25',
#   '25,78',
#   '510\xa0042',
#   '11,28',
#   '2,83',
#   '160\xa0402',
#   'Large Cap Stockholm'],
#  ['28,28',
#   '-3,68',
#   '-44,59',
#   '83\xa0606',
#   '6,44',
#   '0',
#   '106\xa0613',
#   'Large Cap Stockholm'],
#  ['52,50',
#   '3,35',
#   '6,28',
#   '33\xa0528',
#   '-19,02',
#   '1,18',
#   '11\xa0238',
#   'Large Cap Stockholm'],
#  ['92,35',
#   '1,48',
#   '8,26',
#   '27\xa0976',
#   '45,64',
#   '3,41',
#   '9\xa0204',
#   'Large Cap Stockholm']]

# %%
len(values)
# Out:
# 157

# %% [markdown]
# **Data Processing and Formatting in Lists**
#
# An important detail to note is the presence of unusual \xa0 characters in some of the values. These characters are actually non-breaking spaces. In HTML, for instance, the string '58\xa0817' would be displayed as 58&nbsp;817. The &nbsp; entity represents a non-breaking space, which looks like a regular space but behaves differently. It prevents line breaks at that position, making sure that the text remains on the same line. This is often used to separate groups of digits or to attach units to numbers without allowing the browser to break the line at that point.
#
# In addition to these non-breaking spaces, you might also encounter commas used as digit separators. Both of these factors can cause issues during data processing. So, it's important to address and handle these characters appropriately.
#
# After processing, each row in values looks like a combination of floats, integers, and strings, formatted consistently and ready for further analysis or visualization.

# %%
#Handling Special Characters and Comma Replacements
values = [list(map(lambda s: s.replace('\xa0','').replace(',','.'),row)) for row in values]

#Converting String Values to Floats and Integers
values = [list(map(float,row[:3])) + [int(row[3])] + \
          list(map(float,row[4:6])) + [int(row[6])] + [row[7]] for row in values]
values
# Out:
# [[229.6, 1.32, 24.04, 58817, 22.61, 1.21, 9526, 'Large Cap Stockholm'],
#  [441.3, 1.12, 26.81, 803634, 18.74, 2.19, 49168, 'Large Cap Stockholm'],
#  [112.9, 4.25, 2.92, 13776, 44.74, 1.11, 7048, 'Large Cap Stockholm'],
#  [84.75, 3.8, -18.59, 11368, 39.44, 1.22, 3846, 'Large Cap Stockholm'],
#  [216.4, 2.27, 32.44, 57724, 33.81, 1.18, 7876, 'Large Cap Stockholm'],
#  [139.9, 3.25, -25.47, 15810, 12.95, 4.06, 10675, 'Large Cap Stockholm'],
#  [379.2, -0.86, 15.4, 158996, 26.04, 1.57, 23443, 'Large Cap Stockholm'],
#  [76.26, 2.03, 84.25, 19117, 11.83, 1.87, 37970, 'Large Cap Stockholm'],
#  [11.8, 0.85, 5.55, 17085, 8.78, 5.4, 4430, 'Large Cap Stockholm'],
#  [43.12, 1.36, 6.21, 11631, 29.86, 2.0, 12408, 'Large Cap Stockholm'],
#  [285.6, 1.28, 18.8, 318086, 23.39, 1.7, 27552, 'Large Cap Stockholm'],
#  [1423.0, 0.0, -3.98, 2202059, 34.05, 2.13, 62653, 'Large Cap Stockholm'],
#  [166.25, 1.46, 24.29, 769521, 29.22, 1.4, 15412, 'Large Cap Stockholm'],
#  [142.4, 1.32, 21.71, 769521, 25.06, 1.64, 45376, 'Large Cap Stockholm'],
#  [222.2, 1.09, 16.21, 29282, -19.51, 2.41, 4677, 'Large Cap Stockholm'],
#  [1089.0, 1.49, 32.0, 93022, 20.17, 2.66, 7304, 'Large Cap Stockholm'],
#  [223.4, -1.15, 2.95, 35536, 17.94, 3.32, 64688, 'Large Cap Stockholm'],
#  [266.3, -2.95, -6.56, 57681, 26.99, 2.97, 85595, 'Large Cap Stockholm'],
#  [128.9, 1.82, -21.69, 65418, 35.99, 0.74, 10052, 'Large Cap Stockholm'],
#  [111.4, -0.18, 23.78, 15929, 8.41, 0.0, 18391, 'Large Cap Stockholm'],
#  [249.5, 2.04, 80.8, 13832, 22.0, 0.0, 1911, 'Large Cap Stockholm'],
#  [127.7, 2.08, 8.13, 12279, 11.06, 7.03, 13066, 'Large Cap Stockholm'],
#  [97.18, 1.59, -26.24, 24378, 13.56, 5.75, 22250, 'Large Cap Stockholm'],
#  [254.2, 3.25, -17.36, 22397, 84.06, 0.0, 13781, 'Large Cap Stockholm'],
#  [139.7, 5.67, -20.13, 11199, 55.67, 1.21, 3285, 'Large Cap Stockholm'],
#  [288.05, -0.12, -34.25, 78771, 11.28, 5.2, 52692, 'Large Cap Stockholm'],
#  [80.65, 3.07, -25.53, 16577, 12.02, 4.15, 7784, 'Large Cap Stockholm'],
#  [288.6, 3.29, 21.06, 21401, 4.95, 0.81, 37199, 'Large Cap Stockholm'],
#  [587.0, 2.98, 143.16, 32652, 68.86, 0.0, 7923, 'Large Cap Stockholm'],
#  [137.75, 1.89, -0.25, 67761, -6.54, 0.0, 79824, 'Large Cap Stockholm'],
#  [443.4, 0.59, 3.84, 22134, 709.32, 1.87, 3819, 'Large Cap Stockholm'],
#  [10.3, 0.49, -10.43, 15207, -1.3, 3.9, 2545, 'Large Cap Stockholm'],
#  [10.03, 0.8, -3.93, 15207, -1.27, 4.02, 13532, 'Large Cap Stockholm'],
#  [187.0, 0.75, -6.73, 15207, -23.62, 10.78, 4575, 'Large Cap Stockholm'],
#  [206.0, 0.73, -11.21, 15207, -24.7, 9.78, 7010, 'Large Cap Stockholm'],
#  [68.95, 1.77, -16.53, 9321, 44.65, 2.07, 34629, 'Large Cap Stockholm'],
#  [82.3, 1.23, 4.24, 11669, -41.66, 2.46, 10080, 'Large Cap Stockholm'],
#  [88.0, 1.31, 19.99, 28110, 21.23, 1.5, 11448, 'Large Cap Stockholm'],
#  [118.0, -0.84, -37.57, 28731, -10.59, 0.0, 347, 'Large Cap Stockholm'],
#  [101.25, -1.56, -36.32, 28731, -9.15, 0.0, 26883, 'Large Cap Stockholm'],
#  [57.5, 3.14, 17.64, 16497, 19.78, 1.26, 9170, 'Large Cap Stockholm'],
#  [80.66, 0.05, 18.44, 31042, 23.01, 2.98, 10198, 'Large Cap Stockholm'],
#  [24.92, 1.86, -46.81, 33460, 8.29, 0.0, 98933, 'Large Cap Stockholm'],
#  [191.85, 1.48, -7.32, 220322, 23.8, 1.8, 5636, 'Large Cap Stockholm'],
#  [168.6, 1.38, -4.8, 220322, 20.94, 2.04, 17912, 'Large Cap Stockholm'],
#  [264.0, 2.68, 4.39, 321558, -800.32, 1.17, 43218, 'Large Cap Stockholm'],
#  [66.0, 0.3, -3.65, 214241, -9.39, 4.1, 6080, 'Large Cap Stockholm'],
#  [64.04, 1.49, 1.09, 214241, -9.01, 4.28, 75045, 'Large Cap Stockholm'],
#  [264.0, 1.93, -8.97, 182356, 19.88, 2.8, 5066, 'Large Cap Stockholm'],
#  [264.1, 1.69, -8.39, 182356, 19.93, 2.79, 31685, 'Large Cap Stockholm'],
#  [1147.0, -1.31, 2.28, 248808, 20.73, 1.95, 78183, 'Large Cap Stockholm'],
#  [102.4, 1.89, 4.17, 33773, -5.05, 2.39, 10969, 'Large Cap Stockholm'],
#  [68.62, 2.39, 20.47, 78980, -43.57, 0.0, 19748, 'Large Cap Stockholm'],
#  [63.1, 1.12, -25.24, 12306, -5.86, 1.6, 2284, 'Large Cap Stockholm'],
#  [59.7, 0.34, -19.87, 12306, -5.58, 8.4, 3436, 'Large Cap Stockholm'],
#  [750.0, 0.0, -19.09, 10095, 19.4, 2.0, 5147, 'Large Cap Stockholm'],
#  [53.88, 2.01, 7.25, 32207, 67.65, 0.23, 41559, 'Large Cap Stockholm'],
#  [229.1, 1.37, 3.29, 61791, 27.09, 1.88, 26585, 'Large Cap Stockholm'],
#  [111.0, 1.32, -0.49, 219984, 7.81, 5.02, 65540, 'Large Cap Stockholm'],
#  [136.4, 1.34, 3.33, 219984, 9.59, 4.09, 25098, 'Large Cap Stockholm'],
#  [247.6, -1.82, 68.44, 24805, 81.61, 0.4, 6655, 'Large Cap Stockholm'],
#  [169.54, 1.07, 30.18, 273364, 43.51, 3.88, 92218, 'Large Cap Stockholm'],
#  [115.75, 0.7, -2.61, 317402, 29.29, 1.18, 34950, 'Large Cap Stockholm'],
#  [117.9, 1.64, 0.08, 40765, 15.13, 3.1, 5039, 'Large Cap Stockholm'],
#  [511.0, 3.9, 44.19, 23784, 37.62, 0.81, 5051, 'Large Cap Stockholm'],
#  [411.0, 0.74, -6.16, 67192, 14.68, 1.96, 3076, 'Large Cap Stockholm'],
#  [414.9, 1.02, -2.77, 67192, 14.77, 1.95, 20024, 'Large Cap Stockholm'],
#  [136.3, 2.33, -13.52, 28776, -14.07, 2.03, 14932, 'Large Cap Stockholm'],
#  [79.9, 0.76, -1.11, 46320, 25.22, 3.78, 7067, 'Large Cap Stockholm'],
#  [80.34, 0.75, -0.54, 46320, 25.36, 3.76, 24894, 'Large Cap Stockholm'],
#  [324.7, 0.53, 20.13, 140160, 4.62, 2.24, 24840, 'Large Cap Stockholm'],
#  [324.7, 0.56, 20.48, 140160, 4.62, 2.25, 71460, 'Large Cap Stockholm'],
#  [259.7, 1.8, 11.84, 93295, 32.81, 1.02, 12585, 'Large Cap Stockholm'],
#  [43.44, 4.07, 3.13, 11066, 17.75, 1.58, 11004, 'Large Cap Stockholm'],
#  [118.5, 3.54, 15.05, 14535, 6.79, 0.0, 8194, 'Large Cap Stockholm'],
#  [74.02, 5.71, -45.55, 8523, -2.22, 19.28, 43247, 'Large Cap Stockholm'],
#  [229.6, 1.37, 10.7, 706899, 5.85, 1.94, 78460, 'Large Cap Stockholm'],
#  [231.6, 1.31, 13.33, 706899, 5.91, 1.92, 362951, 'Large Cap Stockholm'],
#  [178.6, 3.9, -10.48, 11566, 9.22, 8.14, 18675, 'Large Cap Stockholm'],
#  [93.74, -0.13, -20.12, 21600, 13.1, 4.81, 26981, 'Large Cap Stockholm'],
#  [103.4, 0.39, -37.03, 29185, -4.01, 0.0, 12968, 'Large Cap Stockholm'],
#  [103.15, 1.43, -36.91, 29185, -3.96, 0.0, 116699, 'Large Cap Stockholm'],
#  [133.4, 0.91, 23.63, 27952, 33.04, 1.21, 7152, 'Large Cap Stockholm'],
#  [257.2, 1.82, 19.02, 164941, 27.34, 1.46, 101387, 'Large Cap Stockholm'],
#  [255.0, 2.33, 35.75, 113191, 35.65, 0.72, 16307, 'Large Cap Stockholm'],
#  [187.2, 0.54, 27.09, 14681, 17.24, 2.79, 8490, 'Large Cap Stockholm'],
#  [269.2, 0.6, -7.81, 20145, 11.26, 4.48, 6749, 'Large Cap Stockholm'],
#  [540.2, 1.27, 15.43, 133772, 13.15, 0.75, 42199, 'Large Cap Stockholm'],
#  [119.2, 3.47, 4.01, 28091, 26.23, 3.7, 9508, 'Large Cap Stockholm'],
#  [82.8, 3.18, 10.16, 62089, 14.75, 3.55, 16802, 'Large Cap Stockholm'],
#  [162.9, 4.29, 7.17, 25045, 158.81, 0.88, 2825, 'Large Cap Stockholm'],
#  [191.85, 0.5, 32.49, 32854, -62.98, 0.0, 27464, 'Large Cap Stockholm'],
#  [312.3, 2.06, -25.55, 8107, 122.7, 1.8, 16261, 'Large Cap Stockholm'],
#  [79.0, -1.25, -4.82, 10520, 29.8, 0.0, 585, 'Large Cap Stockholm'],
#  [80.7, 2.87, 0.01, 10520, 29.23, 0.0, 11186, 'Large Cap Stockholm'],
#  [157.1, 2.81, 51.06, 28293, 32.2, 0.62, 7294, 'Large Cap Stockholm'],
#  [280.2, 0.72, 42.89, 27344, 36.94, 1.26, 7607, 'Large Cap Stockholm'],
#  [67.9, 2.34, -3.21, 12686, 30.41, 1.66, 5051, 'Large Cap Stockholm'],
#  [127.0, 0.4, 5.83, 12705, 7.78, 4.74, 2830, 'Large Cap Stockholm'],
#  [127.3, 0.79, 20.21, 12705, 7.77, 4.75, 15534, 'Large Cap Stockholm'],
#  [97.63, 2.19, -14.66, 12934, 10.57, 3.4, 24206, 'Large Cap Stockholm'],
#  [65.02, -0.88, -37.96, 132761, 25.5, 0.99, 115223, 'Large Cap Stockholm'],
#  [52.6, 2.04, -11.0, 14224, 27.44, 3.69, 6886, 'Large Cap Stockholm'],
#  [127.28, 0.36, 5.35, 446150, 7.77, 7.08, 65919, 'Large Cap Stockholm'],
#  [164.8, 2.42, 7.36, 41202, 16.6, 2.86, 5975, 'Large Cap Stockholm'],
#  [216.8, 1.21, -2.34, 13339, 94.01, 2.33, 4668, 'Large Cap Stockholm'],
#  [26.85, -0.19, -3.42, 13339, 35.87, 7.43, 4897, 'Large Cap Stockholm'],
#  [87.45, 5.11, -3.58, 16629, -19.1, 4.81, 10578, 'Large Cap Stockholm'],
#  [54.1, 3.84, -35.56, 14716, 10.79, 0.0, 14392, 'Large Cap Stockholm'],
#  [144.3, 1.33, 9.65, 26512, 40.53, 1.76, 4128, 'Large Cap Stockholm'],
#  [54.0, 0.93, -16.28, 15839, 6.59, 7.48, 37169, 'Large Cap Stockholm'],
#  [37.15, 0.68, -13.5, 11722, 11.22, 2.28, 3621, 'Large Cap Stockholm'],
#  [35.52, 2.48, -11.62, 11722, 10.54, 2.42, 32946, 'Large Cap Stockholm'],
#  [675.4, 2.43, 64.45, 89577, 26.25, 0.8, 61665, 'Large Cap Stockholm'],
#  [258.0, 1.18, -5.49, 91210, 120.64, 1.06, 1202, 'Large Cap Stockholm'],
#  [258.0, 1.65, -6.45, 91210, 120.07, 1.06, 6533, 'Large Cap Stockholm'],
#  [28.0, 1.27, -0.53, 91210, 13.08, 7.23, 10467, 'Large Cap Stockholm'],
#  [5.022, 3.81, -75.79, 8379, -0.27, 0.0, 179285, 'Large Cap Stockholm'],
#  [5.62, 4.93, -74.08, 8379, -0.29, 0.0, 28620, 'Large Cap Stockholm'],
#  [436.5, 0.34, -18.26, 218784, 14.47, 4.59, 4162, 'Large Cap Stockholm'],
#  [215.5, 1.84, 5.38, 269568, 18.32, 2.36, 48017, 'Large Cap Stockholm'],
#  [145.0, 1.4, 0.83, 101776, 25.06, 1.75, 6427, 'Large Cap Stockholm'],
#  [145.0, 1.01, 1.83, 101776, 25.16, 1.74, 39242, 'Large Cap Stockholm'],
#  [144.7, 1.72, 12.34, 310581, 7.98, 4.75, 58514, 'Large Cap Stockholm'],
#  [146.6, 1.1, 7.48, 310581, 8.13, 4.66, 12622, 'Large Cap Stockholm'],
#  [179.64, 1.64, 23.51, 34768, 78.14, 0.0, 7951, 'Large Cap Stockholm'],
#  [99.52, 2.39, 6.42, 57202, 38.09, 3.55, 30856, 'Large Cap Stockholm'],
#  [30.935, 1.24, -36.05, 26018, -78.52, 0.0, 68056, 'Large Cap Stockholm'],
#  [176.6, 1.49, -1.78, 73987, 10.76, 4.31, 45484, 'Large Cap Stockholm'],
#  [197.8, 1.85, 7.85, 89922, 12.56, 3.6, 4165, 'Large Cap Stockholm'],
#  [196.6, 0.95, 8.35, 89922, 12.6, 3.59, 24592, 'Large Cap Stockholm'],
#  [76.5, 1.97, 20.74, 78340, -4.1, 11.6, 23268, 'Large Cap Stockholm'],
#  [76.06, 2.04, 24.69, 78340, -4.07, 11.67, 106509, 'Large Cap Stockholm'],
#  [139.2, 1.75, -15.84, 109933, 21.07, 4.92, 8523, 'Large Cap Stockholm'],
#  [139.5, 1.45, -11.65, 109933, 21.18, 4.89, 14121, 'Large Cap Stockholm'],
#  [8.76, 3.42, 4.21, 14194, 11.63, 0.94, 25336, 'Large Cap Stockholm'],
#  [128.5, 0.78, 12.72, 46550, 26.15, 2.12, 1021, 'Large Cap Stockholm'],
#  [129.3, 2.78, 13.32, 46550, 25.8, 2.15, 8895, 'Large Cap Stockholm'],
#  [208.3, 1.12, 8.77, 236361, 7.1, 4.73, 94999, 'Large Cap Stockholm'],
#  [290.6, 1.61, 28.3, 101735, 35.06, 0.0, 8496, 'Large Cap Stockholm'],
#  [79.9, 1.78, 3.77, 17182, 12.79, 1.4, 4305, 'Large Cap Stockholm'],
#  [90.8, 0.22, -4.82, 61254, 15.46, 7.51, 1022, 'Large Cap Stockholm'],
#  [87.64, -0.07, -4.72, 61254, 14.97, 7.75, 71773, 'Large Cap Stockholm'],
#  [27.39, 0.33, -0.22, 107583, -7.11, 7.33, 63222, 'Large Cap Stockholm'],
#  [260.2, -1.29, 7.08, 28189, 26.27, 3.49, 17105, 'Large Cap Stockholm'],
#  [241.6, 1.43, -22.46, 28139, 13.01, 7.03, 3572, 'Large Cap Stockholm'],
#  [244.4, 0.66, 43.51, 122400, 4.34, 3.35, 9319, 'Large Cap Stockholm'],
#  [337.1, 3.06, 36.37, 83452, 7.7, 1.83, 14672, 'Large Cap Stockholm'],
#  [242.4, 2.02, 23.55, 14436, 34.87, 1.51, 4460, 'Large Cap Stockholm'],
#  [31.81, -0.22, -20.2, 12153, 22.46, 0.0, 11205, 'Large Cap Stockholm'],
#  [592.5, 3.77, 48.35, 21515, 65.25, 0.4, 7604, 'Large Cap Stockholm'],
#  [174.6, 2.11, -14.83, 23250, 57.76, 0.5, 10871, 'Large Cap Stockholm'],
#  [255.6, 1.27, 22.18, 510042, 11.52, 2.77, 15231, 'Large Cap Stockholm'],
#  [250.15, 1.25, 25.78, 510042, 11.28, 2.83, 160402, 'Large Cap Stockholm'],
#  [28.28, -3.68, -44.59, 83606, 6.44, 0.0, 106613, 'Large Cap Stockholm'],
#  [52.5, 3.35, 6.28, 33528, -19.02, 1.18, 11238, 'Large Cap Stockholm'],
#  [92.35, 1.48, 8.26, 27976, 45.64, 3.41, 9204, 'Large Cap Stockholm']]

# %% [markdown]
# Now we can construct a dataframe.

# %%
import pandas as pd                               #pandas
data = list()
for (name,val) in zip(names,values):
    row = { 'Name' : name,
            'Latest' : val[0],
            'Change %' : val[1],
            '1 year %' : val[2],
            'Market value MSEK' : val[3],
            'P/E' : val[4],
            'Dividend yield %' : val[5],
            'Owners' : val[6],
            'List' : val[7]
          }
    data.append(row)
data = pd.DataFrame(data)
data
# Out:
#                       Name  Latest  Change %  1 year %  Market value MSEK  \
# 0                      AAK  229.60      1.32     24.04              58817
# 1                  ABB Ltd  441.30      1.12     26.81             803634
# 2                AddLife B  112.90      4.25      2.92              13776
# 3          Addnode Group B   84.75      3.80    -18.59              11368
# 4                Addtech B  216.40      2.27     32.44              57724
# ..                     ...     ...       ...       ...                ...
# 152                Volvo A  255.60      1.27     22.18             510042
# 153                Volvo B  250.15      1.25     25.78             510042
# 154            Volvo Car B   28.28     -3.68    -44.59              83606
# 155           Wallenstam B   52.50      3.35      6.28              33528
# 156  Wihlborgs Fastigheter   92.35      1.48      8.26              27976
#
#        P/E  Dividend yield %  Owners                 List
# 0    22.61              1.21    9526  Large Cap Stockholm
# 1    18.74              2.19   49168  Large Cap Stockholm
# 2    44.74              1.11    7048  Large Cap Stockholm
# 3    39.44              1.22    3846  Large Cap Stockholm
# 4    33.81              1.18    7876  Large Cap Stockholm
# ..     ...               ...     ...                  ...
# 152  11.52              2.77   15231  Large Cap Stockholm
# 153  11.28              2.83  160402  Large Cap Stockholm
# 154   6.44              0.00  106613  Large Cap Stockholm
# 155 -19.02              1.18   11238  Large Cap Stockholm
# 156  45.64              3.41    9204  Large Cap Stockholm
#
# [157 rows x 9 columns]

# %%
# Display the  AstraZeneca row (indexing starts from 0)
data.iloc[11]
# Out:
# Name                         AstraZeneca
# Latest                            1423.0
# Change %                             0.0
# 1 year %                           -3.98
# Market value MSEK                2202059
# P/E                                34.05
# Dividend yield %                    2.13
# Owners                             62653
# List                 Large Cap Stockholm
# Name: 11, dtype: object

# %%
# Display the First row  (indexing starts from 0)
data.iloc[0]
# Out:
# Name                                 AAK
# Latest                             229.6
# Change %                            1.32
# 1 year %                           24.04
# Market value MSEK                  58817
# P/E                                22.61
# Dividend yield %                    1.21
# Owners                              9526
# List                 Large Cap Stockholm
# Name: 0, dtype: object

# %% [markdown]
# **Saving Processed Data to CSV**
# To export data you can use the to_csv method from pandas.

# %%
data.to_csv('avanza.csv' ,index=None) #save the DataFrame data to a CSV file named avanza.csv without including the row indices.

# %% [markdown]
# Thank you for your attention :)
